# %% [markdown]
# item 카테고리 id 얻기

# %%
import pandas as pd
import numpy as np

# %%
# 아이템, 아이템 카테고리 데이터 불러오기

items = pd.read_csv('../data/items.csv')
items_cat = pd.read_csv('../data/item_categories.csv')

# %%
# 고유값의 수 ( )
# print(items['item_id'].nunique()) 
# print(items_cat['item_category_id'].nunique())

# %%
items.head()
# Out:
#                                            item_name  item_id  \
# 0          ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1  !ABBYY FineReader 12 Professional Edition Full...        1
# 2      ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3    ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4        ***КОРОБКА (СТЕКЛО)                       D        4
#
#    item_category_id
# 0                40
# 1                76
# 2                40
# 3                40
# 4                40

# %%
items.info()

# 아이템 데이터 정보
# 상품: 22,170개, 결측값 없음
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22170 entries, 0 to 22169
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   item_name         22170 non-null  object
#  1   item_id           22170 non-null  int64
#  2   item_category_id  22170 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 519.7+ KB

# %%
items_cat.head()
# Out:
#         item_category_name  item_category_id
# 0  PC - Гарнитуры/Наушники                 0
# 1         Аксессуары - PS2                 1
# 2         Аксессуары - PS3                 2
# 3         Аксессуары - PS4                 3
# 4         Аксессуары - PSP                 4

# %%
items_cat.info()

# 아이템 카테고리 데이터 정보
# 상품분류: 84개, 결측값 없음
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   item_category_name  84 non-null     object
#  1   item_category_id    84 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.4+ KB

# %%
# item과 item category의 결측값, 중복값 확인 

print(items.isnull().sum())
print(items.duplicated().sum())  
print()
print(items_cat.isnull().sum())
print(items_cat.duplicated().sum())  

# 두 값 모두 없다는 것을 확인
# Out:
# item_name           0
# item_id             0
# item_category_id    0
# dtype: int64
# 0
#
# item_category_name    0
# item_category_id      0
# dtype: int64
# 0

# %%
# 데이터 병합 : merge 이용

total_item = pd.merge(items, items_cat, how='left', on=['item_category_id'])
total_item.head()
# Out:
#                                            item_name  item_id  \
# 0          ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1  !ABBYY FineReader 12 Professional Edition Full...        1
# 2      ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3    ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4        ***КОРОБКА (СТЕКЛО)                       D        4
#
#    item_category_id                    item_category_name
# 0                40                            Кино - DVD
# 1                76  Программы - Для дома и офиса (Цифра)
# 2                40                            Кино - DVD
# 3                40                            Кино - DVD
# 4                40                            Кино - DVD

# %%
main_category = total_item['item_category_name'].str.split('-').apply(lambda x : x[0].strip())
main_category.unique()

# item_category_name의 값 : '-' 기준으로 카테고리 대분류, 소분류로 이루어짐
# 대분류 추출 - 대분류 파생피처 만들기
# Out:
# array(['Кино', 'Программы', 'Музыка', 'Игры', 'Игры PC', 'Книги',
#        'Подарки', 'Карты оплаты (Кино, Музыка, Игры)', 'Аксессуары',
#        'Игры MAC', 'Игры Android', 'Игровые консоли', 'PC',
#        'Карты оплаты', 'Билеты (Цифра)', 'Служебные', 'Доставка товара',
#        'Чистые носители (штучные)', 'Чистые носители (шпиль)',
#        'Элементы питания'], dtype=object)

# %%
sub_category = total_item['item_category_name'].str.split('-').apply(lambda x : x[1].strip() if len(x) > 1 else x[0])
sub_category.unique()

# 소분류 추출
# '-'로 분리되지 않는, 한 단어로 되어 있는 경우에는 대분류로 생각함
# Out:
# array(['DVD', 'Для дома и офиса (Цифра)', 'CD локального производства',
#        'PS3', 'Стандартные издания', 'XBOX 360', 'Blu', 'Коллекционное',
#        'MP3', 'Аудиокниги', 'Обучающие (Цифра)', 'Цифра',
#        'Методические материалы 1С', 'Аудиокниги (Цифра)', 'Аудиокниги 1С',
#        'Обучающие', '1С:Предприятие 8', 'Для дома и офиса', 'Винил',
#        'CD фирменного производства', 'Развитие', 'Музыкальное видео',
#        'Подарочные издания', 'MAC (Цифра)', 'PSP',
#        'Дополнительные издания', 'PS4', 'XBOX ONE',
#        'Коллекционные издания', 'Сувениры (в навеску)', 'PSVita',
#        'Карты оплаты (Кино, Музыка, Игры)', 'Гаджеты, роботы, спорт',
#        'Аксессуары для игр', 'Фигурки', 'Мягкие игрушки', 'PS2',
#        'Настольные игры', 'Сертификаты, услуги', 'Гарнитуры/Наушники',
#        'PSN', 'Настольные игры (компактные)', 'Компьютерная литература',
#        'Сумки, Альбомы, Коврики д/мыши', 'Сувениры', 'Live!',
#        'Live! (Цифра)', 'Открытки, наклейки', 'Путеводители',
#        'Бизнес литература', 'Артбуки, энциклопедии', 'Атрибутика',
#        'Билеты (Цифра)', 'Билеты', 'Доставка товара', 'Прочие',
#        'Windows (Цифра)', 'Комиксы, манга', 'Чистые носители (штучные)',
#        'Чистые носители (шпиль)', 'Открытки', 'Познавательная литература',
#        'Служебные', 'Художественная литература', 'Элементы питания'],
#       dtype=object)

# %%
total_item['main_category'] = main_category
total_item['sub_category'] = sub_category

# %%
total_item
# Out:
#                                                item_name  item_id  \
# 0              ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1      !ABBYY FineReader 12 Professional Edition Full...        1
# 2          ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3        ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4            ***КОРОБКА (СТЕКЛО)                       D        4
# ...                                                  ...      ...
# 22165             Ядерный титбит 2 [PC, Цифровая версия]    22165
# 22166    Язык запросов 1С:Предприятия  [Цифровая версия]    22166
# 22167  Язык запросов 1С:Предприятия 8 (+CD). Хрустале...    22167
# 22168                                Яйцо для Little Inu    22168
# 22169                      Яйцо дракона (Игра престолов)    22169
#
#        item_category_id                    item_category_name main_category  \
# 0                    40                            Кино - DVD          Кино
# 1                    76  Программы - Для дома и офиса (Цифра)     Программы
# 2                    40                            Кино - DVD          Кино
# 3                    40                            Кино - DVD          Кино
# 4                    40                            Кино - DVD          Кино
# ...                 ...                                   ...           ...
# 22165                31                       Игры PC - Цифра       Игры PC
# 22166                54                         Книги - Цифра         Книги
# 22167                49     Книги - Методические материалы 1С         Книги
# 22168                62      Подарки - Гаджеты, роботы, спорт       Подарки
# 22169                69                    Подарки - Сувениры       Подарки
#
#                     sub_category
# 0                            DVD
# 1       Для дома и офиса (Цифра)
# 2                            DVD
# 3                            DVD
# 4                            DVD
# ...                          ...
# 22165                      Цифра
# 22166                      Цифра
# 22167  Методические материалы 1С
# 22168     Гаджеты, роботы, спорт
# 22169                   Сувениры
#
# [22170 rows x 6 columns]

# %%
# 카테고리 대분류, 소분류 숫자 라벨링

# 사이킷런에서 라벨인코더를 임포트
from sklearn.preprocessing import LabelEncoder

# 레이블 인코더 생성
label = LabelEncoder()

# category별 숫자 label 작업
total_item['main_type_id'] = label.fit_transform(total_item['main_category'])
total_item['sub_type_id'] = label.fit_transform(total_item['sub_category'])

# %%
total_item
# Out:
#                                                item_name  item_id  \
# 0              ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1      !ABBYY FineReader 12 Professional Edition Full...        1
# 2          ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3        ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4            ***КОРОБКА (СТЕКЛО)                       D        4
# ...                                                  ...      ...
# 22165             Ядерный титбит 2 [PC, Цифровая версия]    22165
# 22166    Язык запросов 1С:Предприятия  [Цифровая версия]    22166
# 22167  Язык запросов 1С:Предприятия 8 (+CD). Хрустале...    22167
# 22168                                Яйцо для Little Inu    22168
# 22169                      Яйцо дракона (Игра престолов)    22169
#
#        item_category_id                    item_category_name main_category  \
# 0                    40                            Кино - DVD          Кино
# 1                    76  Программы - Для дома и офиса (Цифра)     Программы
# 2                    40                            Кино - DVD          Кино
# 3                    40                            Кино - DVD          Кино
# 4                    40                            Кино - DVD          Кино
# ...                 ...                                   ...           ...
# 22165                31                       Игры PC - Цифра       Игры PC
# 22166                54                         Книги - Цифра         Книги
# 22167                49     Книги - Методические материалы 1С         Книги
# 22168                62      Подарки - Гаджеты, роботы, спорт       Подарки
# 22169                69                    Подарки - Сувениры       Подарки
#
#                     sub_category  main_type_id  sub_type_id
# 0                            DVD            11            4
# 1       Для дома и офиса (Цифра)            15           31
# 2                            DVD            11            4
# 3                            DVD            11            4
# 4                            DVD            11            4
# ...                          ...           ...          ...
# 22165                      Цифра             8           61
# 22166                      Цифра            12           61
# 22167  Методические материалы 1С            12           39
# 22168     Гаджеты, роботы, спорт            14           28
# 22169                   Сувениры            14           56
#
# [22170 rows x 8 columns]

# %%
# 숫자 라벨링 후 확인작업

total_item.isnull().sum()
# Out:
# item_name             0
# item_id               0
# item_category_id      0
# item_category_name    0
# main_category         0
# sub_category          0
# main_type_id          0
# sub_type_id           0
# dtype: int64

# %%
# 라벨링된 컬럼만 모음

pre_items = total_item[['item_id', 'item_category_id', 'main_type_id', 'sub_type_id']]
pre_items.head()
# Out:
#    item_id  item_category_id  main_type_id  sub_type_id
# 0        0                40            11            4
# 1        1                76            15           31
# 2        2                40            11            4
# 3        3                40            11            4
# 4        4                40            11            4

# %%
pre_items.to_csv('../pre_data/pre_items.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-939603412599> in <module>
# ----> 1 pre_items.to_csv('../pre_data/pre_items.csv')
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3464         )
#    3465
# -> 3466         return DataFrameRenderer(formatter).to_csv(
#    3467             path_or_buf,
#    3468             line_terminator=line_terminator,
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/formats/csvs.py in save(self)
#     235         """
#     236         # apply compression and byte/text conversion
# --> 237         with get_handle(
#     238             self.filepath_or_buffer,
#     239             self.mode,
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../pre_data/pre_items.csv'
